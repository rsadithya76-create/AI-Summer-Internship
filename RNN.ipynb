# %% [markdown]
# <a href="https://colab.research.google.com/github/rsadithya76-create/AI-Summer-Internship/blob/main/RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers ,models

# %%
mnist=keras.datasets.mnist
(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train,x_test=x_train / 255.0 , x_test /255.0            # / by 255 for normalization

# %%
input_shape=(28,28)
inputs=layers.Input(shape=input_shape)
rrn_layer=layers.LSTM(128)(inputs)
outputs=layers.Dense(10,activation='softmax')(rrn_layer)
model=models.Model(inputs=inputs,outputs=outputs)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(x_train,y_train,validation_split=0.2,epochs=20)
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 53s 34ms/step - accuracy: 0.8785 - loss: 0.3795 - val_accuracy: 0.9459 - val_loss: 0.1703
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 51s 34ms/step - accuracy: 0.9633 - loss: 0.1210 - val_accuracy: 0.9690 - val_loss: 0.1015
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 51s 34ms/step - accuracy: 0.9744 - loss: 0.0826 - val_accuracy: 0.9723 - val_loss: 0.0902
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 49s 33ms/step - accuracy: 0.9805 - loss: 0.0650 - val_accuracy: 0.9796 - val_loss: 0.0681
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 85s 35ms/step - accuracy: 0.9841 - loss: 0.0518 - val_accuracy: 0.9818 - val_loss: 0.0619
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 52s 35ms/step - accuracy: 0.9862 - loss: 0.0465 - val_accuracy: 0.9800 - val_loss: 0.0662
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 80s 34ms/step - accuracy: 0.9890 - loss: 0.0364 - val_accuracy: 0.9839 - val_loss: 0.0593
# Epoch 8/20
# ...
