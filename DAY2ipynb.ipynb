# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('i1.csv')
df2=pd.read_csv('i2.csv')

# %%
df=df1.merge(df2,how='outer')

# %%
df
# Out:
#              Date            Timestamp  Invoice No.  \
# 0      2023-04-01  2023-04-01 13:16:03        23465
# 1      2023-04-01  2023-04-01 13:16:03        23465
# 2      2023-04-01  2023-04-01 13:16:03        23465
# 3      2023-04-01  2023-04-01 13:16:03        23465
# 4      2023-04-01  2023-04-01 13:16:03        23465
# ...           ...                  ...          ...
# 15616  2023-09-19  2023-09-19 22:03:44        28389
# 15617  2023-09-19  2023-09-19 22:03:44        28389
# 15618  2023-09-19  2023-09-19 22:03:44        28389
# 15619  2023-09-19  2023-09-19 22:03:44        28389
# 15620  2023-09-19  2023-09-19 22:03:44        28389
#
#                          Item Name  Price  Qty.  Sub Total  Discount    Tax  \
# 0              Babycorn Manchurian  160.0   1.0      160.0       0.0   8.00
# 1                Chicken Kati Roll  120.0   1.0      120.0       0.0   6.00
# 2             Paneer Butter Masala  150.0   2.0      300.0       0.0  15.00
# ...

# %%
df1.shape
# Out:
# (7242, 16)

# %%
df2.shape
# Out:
# (8379, 16)

# %%
df.shaped
# Out:
# (15621, 16)

# %%
df.isnull().sum()
# Out:
# Date               0
# Timestamp          0
# Invoice No.        0
# Item Name          0
# Price              0
# Qty.               0
# Sub Total          0
# Discount           0
# Tax                0
# Final Total        0
# Table No.          8
# Server Name        0
# Covers             0
# Variation      15606
# Category           0
# HSN            15621
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15621 entries, 0 to 15620
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         15621 non-null  object
#  1   Timestamp    15621 non-null  object
#  2   Invoice No.  15621 non-null  int64
#  3   Item Name    15621 non-null  object
#  4   Price        15621 non-null  float64
#  5   Qty.         15621 non-null  float64
#  6   Sub Total    15621 non-null  float64
#  7   Discount     15621 non-null  float64
#  8   Tax          15621 non-null  float64
#  9   Final Total  15621 non-null  float64
#  10  Table No.    15613 non-null  float64
#  11  Server Name  15621 non-null  object
#  12  Covers       15621 non-null  int64
#  13  Variation    15 non-null     object
#  14  Category     15621 non-null  object
#  15  HSN          0 non-null      float64
# dtypes: float64(8), int64(2), object(6)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#         Invoice No.         Price          Qty.     Sub Total      Discount  \
# count  15621.000000  15621.000000  15621.000000  15621.000000  15621.000000
# mean   25989.963127    116.608988      1.338839    147.407080      1.262818
# std     1433.192998     63.663769      0.949814    210.127442      6.656396
# min    23465.000000     12.000000      1.000000     12.000000      0.000000
# 25%    24751.000000     50.000000      1.000000     80.000000      0.000000
# 50%    25980.000000    140.000000      1.000000    150.000000      0.000000
# 75%    27274.000000    160.000000      1.000000    170.000000      0.000000
# max    28389.000000    770.000000     28.000000  21560.000000    288.000000
#
#                 Tax   Final Total     Table No.   Covers  HSN
# count  15621.000000  15621.000000  15613.000000  15621.0  0.0
# mean       7.303668    153.447930     18.068340      0.0  NaN
# std       10.461474    219.678163     17.191377      0.0  NaN
# ...

# %%
df.head(100)
# Out:
#           Date            Timestamp  Invoice No.                    Item Name  \
# 0   2023-04-01  2023-04-01 13:16:03        23465          Babycorn Manchurian
# 1   2023-04-01  2023-04-01 13:16:03        23465            Chicken Kati Roll
# 2   2023-04-01  2023-04-01 13:16:03        23465         Paneer Butter Masala
# 3   2023-04-01  2023-04-01 13:16:03        23465                 Pulka (2 No)
# 4   2023-04-01  2023-04-01 13:16:03        23465  Schewan  Chicken Fried Rice
# ..         ...                  ...          ...                          ...
# 95  2023-04-01  2023-04-01 21:51:20        23496                Mineral Water
# 96  2023-04-01  2023-04-01 21:51:20        23496   Tandoor Chicken ( Quarter)
# 97  2023-04-01  2023-04-01 21:51:20        23496               Veg Fried Rice
# 98  2023-04-01  2023-04-01 21:51:51        23497                  Garlic Naan
# 99  2023-04-01  2023-04-01 21:51:51        23497         Paneer Butter Masala
#
# ...

# %%
df.tail(20)
# Out:
#              Date            Timestamp  Invoice No.  \
# 15601  2023-09-19  2023-09-19 21:29:17        28387
# 15602  2023-09-19  2023-09-19 21:29:17        28387
# 15603  2023-09-19  2023-09-19 21:29:17        28387
# 15604  2023-09-19  2023-09-19 21:29:17        28387
# 15605  2023-09-19  2023-09-19 21:31:14        28388
# 15606  2023-09-19  2023-09-19 21:31:14        28388
# 15607  2023-09-19  2023-09-19 21:31:14        28388
# 15608  2023-09-19  2023-09-19 21:31:14        28388
# 15609  2023-09-19  2023-09-19 21:31:14        28388
# 15610  2023-09-19  2023-09-19 21:31:14        28388
# 15611  2023-09-19  2023-09-19 21:31:14        28388
# 15612  2023-09-19  2023-09-19 21:31:14        28388
# 15613  2023-09-19  2023-09-19 21:31:14        28388
# 15614  2023-09-19  2023-09-19 21:31:14        28388
# 15615  2023-09-19  2023-09-19 22:03:44        28389
# 15616  2023-09-19  2023-09-19 22:03:44        28389
# 15617  2023-09-19  2023-09-19 22:03:44        28389
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15621 entries, 0 to 15620
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         15621 non-null  object
#  1   Timestamp    15621 non-null  object
#  2   Invoice No.  15621 non-null  int64
#  3   Item Name    15621 non-null  object
#  4   Price        15621 non-null  float64
#  5   Qty.         15621 non-null  float64
#  6   Sub Total    15621 non-null  float64
#  7   Discount     15621 non-null  float64
#  8   Tax          15621 non-null  float64
#  9   Final Total  15621 non-null  float64
#  10  Table No.    15613 non-null  float64
#  11  Server Name  15621 non-null  object
#  12  Covers       15621 non-null  int64
#  13  Variation    15 non-null     object
#  14  Category     15621 non-null  object
#  15  HSN          0 non-null      float64
# dtypes: float64(8), int64(2), object(6)
# memory usage: 1.9+ MB

# %%
df=df.drop(["Server Name","Covers","Table No.","Variation","HSN","Discount"],axis=1)

# %%
df.shape
# Out:
# (15621, 10)

# %%
tot=df["Final Total"].sum()

# %%
a=df["Invoice No."].nunique()

# %%
b=tot/a
print(b)
# Out:
# 486.70256243654825

# %%
b=df.groupby("Item Name")["Qty."].sum().sort_values(ascending=False)[0:5]
sns.barplot(b)
# Out:
# <Axes: xlabel='Item Name', ylabel='Qty.'>

# %%
b=df.groupby("Item Name")["Final Total"].sum().sort_values(ascending=False)[0:10]
b.plot(kind="bar")
# Out:
# <Axes: xlabel='Item Name'>

# %%
b=df.groupby("Date")["Final Total"].sum()
print(b["2023-09-15"])
# Out:
# 21042.02

# %%
df[(df["Date"]=="2023-09-15") & (df["Item Name"]=="Chicken Noodles")]["Qty."].sum()
# Out:
# np.float64(7.0)

# %%
e=df.groupby("Invoice No.")["Final Total"]["Qty."].sum()
e[e>2000]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_3814/1081042667.py in <cell line: 0>()
# ----> 1 e=df.groupby("Invoice No.")["Final Total"]["Qty."].sum()
#       2 e[e>2000]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     232     def __getitem__(self, key):
#     233         if self._selection is not None:
# --> 234             raise IndexError(f"Column(s) {self._selection} already selected")
#     235
#     236         if isinstance(key, (list, tuple, ABCSeries, ABCIndex, np.ndarray)):
#
# IndexError: Column(s) Final Total already selected

# %%
e=df.groupby("Invoice No.")["Final Total"].sum()
e[e==2887.50]
# Out:
# Invoice No.
# 28126    2887.5
# Name: Final Total, dtype: float64

# %%
e=df.groupby("Invoice No.")["Final Total"].sum()
f=e[e==28145]
f
# Out:
# Series([], Name: Final Total, dtype: float64)

# %%
a=df[df["Invoice No."]==28145]
print(a["Final Total"].sum())
print(a["Qty."].sum())
print(a["Item Name"])
# Out:
# 4078.68
# 40.0
# 14830                      Butter Chicken Gravy
# 14831                      Butter Chicken Gravy
# 14832                               Butter Naan
# 14833    Chicken Biriyani With Raitha And Gravy
# 14834                   Chicken Chettinad Gravy
# 14835                Chicken Pallipalayam Gravy
# 14836                                   Fish 65
# 14837                               Garlic Naan
# 14838                                  Gobi- 65
# 14839                              Kadai Paneer
# 14840                     Kozhi Milaghuperattal
# 14841                             Mineral Water
# 14842          Pepper Tandoori Chicken ( Full )
# 14843          Pepper Tandoori Chicken ( Half )
# 14844                        Romali Roti (1 No)
# 14845               Schewan  Chicken Fried Rice
# 14846                    Schewan Chicken Noodle
# 14847                      Schezwan Veg Noodles
# Name: Item Name, dtype: object

# %%
from matplotlib import axes
from wordcloud import WordCloud
txt=' '.join(df['Item Name'].dropna().astype(str))
wordcloud=WordCloud(max_font_size=50,max_words=100,background_color="white").generate(txt)
fig,ax=plt.subplots(1,1,figsize=(10,10))
ax.imshow(wordcloud,interpolation='bicubic')

ax.set_xticks([])
ax.set_yticks([])
plt.show()

# %%
from matplotlib import axes
from wordcloud import WordCloud
txt=' '.join(df['Item Name'].dropna().astype(str))
wordcloud=WordCloud(max_font_size=50,max_words=100,background_color="white").generate(txt)
fig,ax=plt.subplots(1,1,figsize=(10,10))
ax.imshow(wordcloud,interpolation='nearest')

ax.set_xticks([])
ax.set_yticks([])
plt.show()

# %%
from matplotlib import axes
from wordcloud import WordCloud
txt=' '.join(df['Item Name'].dropna().astype(str))
wordcloud=WordCloud(max_font_size=50,max_words=100,background_color="white").generate(txt)
fig,ax=plt.subplots(1,1,figsize=(10,10))
ax.imshow(wordcloud,interpolation='spline36')

ax.set_xticks([])
ax.set_yticks([])
plt.show()
